# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weekdays= ['Mon.','Tues.','Wed.','Thurs.','Fri.']
xvalues =[1,2,3,4,5]
#plt.xticks(weekdays,xvalues, rotation=60)

Asleep = [7,7,7.5,8.5,6.5]
plt.figure()
plt.title("Aaron's Trends Over the Week", size='xx-large')
plt.ylabel('Hours', size='x-large')
plt.xlabel('Week Day', size='x-large')
plt.ylim([0,13])
plt.plot(Asleep, 'b.-', markersize=10, linewidth=2, label='Sleep', color="#2678B2")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Aess = [3.1,2.4,3,2.9,2]
plt.plot(Aess, 'r.-', markersize=10, linewidth=2, label='Essential Activities', color="#FD7F28")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Adown = [2,2,3,2,5]
plt.plot(Adown, 'g.-', markersize=10, linewidth=2, label='Downtime', color="#329F34")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Amen = [1,4,3,2,4]
plt.plot(Amen, 'y.-', markersize=10, linewidth=2, label='Mental, Phys. Health', color="#D42A2F")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.15,0.70),scatterpoints=1)

Awork = [11,8,7,9,6]
plt.plot(Awork, 'r.-', markersize=10, linewidth=2, label='Work', color="#936ABB")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(1.1,0.64),scatterpoints=1)

# %%
Msleep = [8,7,6,8,5]
plt.figure()
plt.title("Melissa's Trends Over the Week", size='xx-large')
plt.ylabel('Hours', size='x-large')
plt.xlabel('Week Day', size='x-large')
plt.ylim([0,13])
plt.plot(Msleep, 'b.-', markersize=10, linewidth=2, label='Sleep', color="#2678B2")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Mess = [2,2,2,2,2]
plt.plot(Mess, 'r.-', markersize=10, linewidth=2, label='Essential Activities', color="#FD7F28")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Mdown = [1,3,2,1,3]
plt.plot(Mdown, 'g.-', markersize=10, linewidth=2, label='Downtime', color="#329F34")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Mmen = [1,1,2,1,2]
plt.plot(Mmen, 'y.-', markersize=10, linewidth=2, label='Mental, Phys. Health', color="#D42A2F")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.15,0.70),scatterpoints=1)

Mwork = [12,11,12,12,12]
plt.plot(Mwork, 'r.-', markersize=10, linewidth=2, label='Work', color="#936ABB")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(1.1,0.64),scatterpoints=1)

# %%
Fsleep = [9,9,9,6.5,8.5]
plt.figure()
plt.title("Fiona's Trends Over the Week", size='xx-large')
plt.ylabel('Hours', size='x-large')
plt.xlabel('Week Day', size='x-large')
plt.ylim([0,13])
plt.plot(Fsleep, 'b.-', markersize=10, linewidth=2, label='Sleep', color="#2678B2")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Fess = [2.5,3,3,4,3]
plt.plot(Fess, 'r.-', markersize=10, linewidth=2, label='Essential Activities', color="#FD7F28")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Fdown = [2.5,3,2,4,6]
plt.plot(Fdown, 'g.-', markersize=10, linewidth=2, label='Downtime', color="#329F34")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.25,0.75),scatterpoints=1)

Fmen = [2,1,1,4,1]
plt.plot(Fmen, 'y.-', markersize=10, linewidth=2, label='Mental, Phys. Health', color="#D42A2F")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(0.15,0.70),scatterpoints=1)

Fwork = [8,8,9,6,8]
plt.plot(Fwork, 'r.-', markersize=10, linewidth=2, label='Work', color="#936ABB")
plt.tick_params(axis='both', which='major', labelsize=14)
plt.legend(loc=(1.1,0.64),scatterpoints=1)

# %%
list1 = ['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday']
mockdata = pd.Series(list1)

# %%
def two_scales(ax1, time, data1, data2, c1, c2):
    """

    Parameters
    ----------
    ax : axis
        Axis to put two scales on

    time : array-like
        x-axis values for both datasets

    data1: array-like
        Data for left hand scale

    data2 : array-like
        Data for right hand scale

    c1 : color
        Color for line 1

    c2 : color
        Color for line 2

    Returns
    -------
    ax : axis
        Original axis
    ax2 : axis
        New twin axis
    """
    ax2 = ax1.twinx()

    ax1.plot(time, data1, color=c1)
    ax1.set_xlabel('Hour in Day')
    ax1.set_ylabel('Average Distance (Mi)')

    ax2.plot(time, data2, color=c2)
    ax2.set_ylabel('Average Flights Climbed')
    return ax1, ax2

# %%
# Create some mock data
t = s1.index
s1 = grouped[grouped.columns[0]]
s2 = grouped[grouped.columns[1]]

# Create axes
fig, ax = plt.subplots()
ax1, ax2 = two_scales(ax, t, s1, s2, 'r', 'b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3837b021c31e> in <module>()
#       1 # Create some mock data
#       2 t = mockdata.index
# ----> 3 s1 = grouped[grouped.columns[0]]
#       4 s2 = grouped[grouped.columns[1]]
#       5
#
# NameError: name 'grouped' is not defined
